# %% [markdown]
# # The Rapid Transport and Spacial Compartment Model for London
#
# Although, the rapid tranport method can apply arbitrary model, we use SEAIR model here.
# The dynamical equations are given as
#
# \begin{align}
# \dot{S_{in}}	    &=-\lambda_{in}(t)S_{in}+\sigma_{in},\\
# \dot{E}_{in}	    &=\lambda_{in}(t)S_{in}-\gamma_{E}E_{in},\\
# \dot{A}_{in}	    &=\gamma_{E}E_{in}-\gamma_{A}A_{in},\\
# \dot{I}_{in}        &=\gamma_{A}A_{in}-\gamma_{I}I_{in},\\
# \dot{R}_{in}        &=\gamma_{I}I_{in}.\\
# \end{align}

# %%
import numpy as np
import pyrossgeo
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import sys
import gc

# %% [markdown]
# In this notebook, we perform the rapid transport model.
# The key idea of mean-field model is to note that the rate of infection of a susceptible individual in age group `i` at the node `n` is given as
#
# \begin{align}
# \lambda_{in}(t)=\lambda^0_{in}(t)=\beta\sum_{j=1}^{M}C_{ij}\frac{A_{jn} + I_{jn}^{s}}{N^{H}_{jn}},
# \end{align}
#
#
# Commute can then be modeled by changing this to
#
#
# \begin{align}
# \lambda_{in}^{T}(t)=\beta r^{T}\sum_{j=1}^{M}\sum_{m=1}^{N_{d}} \sum_{<k,l>} C_{ij} \frac{D_{j,kl}}{N^{H}_{j,l}} \frac{A_{jl} + I_{jl}}{N^{T}_{j,mn}} \frac{D_{i,mn}}{N^{H}_{i,n}},
# \end{align}
#
#
# while workplace interaction can be modeled as
#
#
# \begin{align}
# \lambda_{in}^{W}(t)=\beta r^{W}\sum_{j=1}^{M}\sum_{m,k=1}^{N_{d}} C_{ij} \frac{D_{j,mk}}{N^{H}_{jk}} \frac{A_{jk} + I_{jk}}{N^{W}_{jm}}  \frac{D_{i,mn}}{N^{H}_{in}}.
# \end{align}
#
# The derivation of all equations is wrriten in [the documentation](https://github.com/lukastk/PyRossGeo/tree/master/docs/mft-model.pdf).
# The simulation then runs by choosing appropriate $\lambda$ as a function of time. The constants $r_T$ and $r_W$ control the strength of interactions. In this model, we assume that each route between the nodes connectsneighbour nodes only.
#
# The defiintion of the variables are in following.
# $D_{i,nm}$ is the number of people working at node `n` and livingin `m` in the age group `i`, $N^{H}_{in}=\sum_{m} D_{i,mn}$ is the total number of residence in node `n` and $N^{W}_{in}=\sum_{m} D_{i,nm}$ is the total number of people working at node `n`.
# $N_{i,nm}^{T}$ is the effective number of the commuter in the age group `i` using the route between `n` and `m`:
#
# \begin{align}
# N^{T}_{i,nm}=\sum_{<kl>}R_{i,kl}\frac{d_{kl}}{d_{nm}},
# \end{align}
#
# where $<kl>$ indicate summation of all pair of neighbour node $k$ and $l$ included in the shortest path between node
# `n` and `m` and $d_{nm}$ is the distance between node `n` and `m` along the shortest path. $R_{i,nm}=\sum_{<kl>}D_{i,kl}$ is the number of the commuter in the age group `i` using the route between the neighbor node `n` and `m`. The node `n` and `m` are included in the shortest path between node pair
# $(k,l)$ took up all combinations satisfying the conditions.
# Hence, we only need $D_{i,nm}$ and $d_{nm}$ in order to construct this network model. $D_{i,nm}$ can be obtained census datasets and $d_{nm}$ can be determined by the geographical locations. For the calculation of London including 983 nodes, $D_{i,nm}$ and $d_{nm}$ are stored CSV files.
#
# We also perform the spacial compartment model that is a time coarse-grained rapid transport model. In this model, we only used time-averaged the infection rate of a susceptible individual in age group `i` at the node `n` is given as
#
# \begin{align}
# \hat{\lambda}_{in}(t)=\frac{1}{T}\int^{T}_{0} \lambda_{in}(t)dt.
# \end{align}
#
# From this time coarse-grained, we can use large incrementation time.

# %% [markdown]
# ## Model define

# %%
model_def = {
    "settings" : {
        #"classes" : ["S", "E", "A", "I", "R"],
        "classes" : ["S", "E", "A", "I"],
        "stochastic_threshold_from_below" : [1000, 1000, 1000, 1000],
        "stochastic_threshold_from_above" : [500, 500, 500, 500],
        "contact_scaling" : "powerlaw",
        "contact_scaling_parameters" : [0, 1.0, 0.5] # a + b * rho^c
    },

    "S" : {
        "linear"    : [],
        "infection" : [ ["I", "-beta"], ["A", "-beta"] ]
    },

    "E" : {
        "linear"    : [ ["E", "-gE"] ],
        "infection" : [ ["I", "beta"], ["A", "beta"]]
    },

    "A" : {
        "linear"    : [ ["E", "gE"], ["A", "-gA"] ],
        "infection" : []
    },

    "I" : {
        "linear"    : [ ["A", "gA"], ["I", "-gI"] ],
        "infection" : []
    }#,

    #"R" : {
    #    "linear"    : [ ["I", "gI"] ],
    #    "infection" : []
    #}
}

# %% [markdown]
# ## Loading $D_{i,nm}$ and $Area$ from csv files.

# %%
M = 9 #Aged Group

sim_config_path = 'london_simulation'
#sim_config_path = 'london_simulation'
tot_pop = pd.read_csv("%s/node_populations.csv" % sim_config_path)
#tot_pop.head()
CSV_Nh = tot_pop.values
Nd = len(tot_pop) # The number of nodes

Nh = np.zeros((M + 1,Nd)) # The population of ususal residence
for i in range(Nd):
    for alp in range(M):
        Nh[alp,i] = CSV_Nh[i,alp + 2]

cn = pd.read_csv("%s/commuter_networks.csv" % sim_config_path, usecols=["Home", "From", "To", "Age", "# to move"])
#cn.head()
CSV_Dnm = cn.values

ii16 = np.iinfo(np.uint16)
Dnm_Max = np.amax(CSV_Dnm[:,4])
print('Max Dnm', Dnm_Max)
if ii16.max < Dnm_Max:
      print('Dnm is too large to calculate.')

census_matrix = np.zeros((M, Nd, Nd), dtype=np.uint16)
for i in range(len(CSV_Dnm)):
    if CSV_Dnm[i,0] == CSV_Dnm[i,1]:
        census_matrix[CSV_Dnm[i,3], CSV_Dnm[i,2], CSV_Dnm[i,0]] = CSV_Dnm[i,4]
        
for alp in range(M):
    for i in range(Nd): # Home node
        census_matrix[alp,i,i] = Nh[alp,i] - np.sum(census_matrix[alp,:,i])
        
df = pd.read_csv('area.csv')
Area = df.values[:,1]/10**6
        
del tot_pop
del CSV_Nh
del cn
del CSV_Dnm
del df
gc.collect()
# Out:
# Max Dnm 1064
# 0

# %% [markdown]
# ## Loading $d_{nm}$ from distances.txt

# %%
#distances=np.ones((Nd, Nd))
    
#Make Total
#for i in range(Nd):
#    for j in range(Nd):
#        #for alp in range(M):
#        census_matrix[M,i,j] = np.sum(census_matrix[:,i,j])
                
Nh = np.zeros((M + 1,Nd)) # The population of ususal residence
Nw = np.zeros((M + 1,Nd)) # The number of people working in specific node.
for alp in range(M):
    for i in range(Nd):
        #Nh[alp,i] = 0.
        #Nw[alp,i] = 0.
        #for j in range(Nd):
        Nh[alp,i] = np.sum(census_matrix[alp,:,i])
        Nw[alp,i] = np.sum(census_matrix[alp,i,:])
#for alp in range(M):
for i in range(Nd):
    Nh[M,i] = np.sum(Nh[:,i]) ## N^{H}_{i} residence in Node i
    Nw[M,i] = np.sum(Nw[:,i]) ## N^{W}_{i} working in Node i
        
# set the matarix D_{nm}
Dnm = census_matrix #.copy()

# set the matarix d_{nm}
dnm = 1#distances #.copy()

max_wid = np.argsort(Nw[M])[Nd- 1]
print("Maxmimum City at Working", max_wid, Nw[M,max_wid])
max_rid = np.argsort(Nh[M])[Nd- 1]
print("Maxmimum City of Residence", max_rid, Nh[M,max_rid])
#sorted_Nh = np.argsort(Nh[M])
#for i in range(50):
#    print('No.', i, sorted_Nh[Nd - 1 -i], Nh[M,sorted_Nh[Nd - 1 -i]])
# Out:
# Maxmimum City at Working 0 247971.0
# Maxmimum City of Residence 701 24719.0

# %% [markdown]
# ## Contact matrices
#
# Define the contact matrices

# %%
C_home = np.array( [
    [5.0,4.83,4.69,4.58,4.48,4.4,4.33,4.28,4.23],
    [4.83,5.0,4.83,4.69,4.58,4.48,4.4,4.33,4.28],
    [4.69,4.83,5.0,4.83,4.69,4.58,4.48,4.4,4.33],
    [4.58,4.69,4.83,5.0,4.83,4.69,4.58,4.48,4.4],
    [4.48,4.58,4.69,4.83,5.0,4.83,4.69,4.58,4.48],
    [4.4,4.48,4.58,4.69,4.83,5.0,4.83,4.69,4.58],
    [4.33,4.4,4.48,4.58,4.69,4.83,5.0,4.83,4.69],
    [4.28,4.33,4.4,4.48,4.58,4.69,4.83,5.0,4.83],
    [4.23,4.28,4.33,4.4,4.48,4.58,4.69,4.83,5.0],
] )
    
C_school = np.array( [
    [8.0,7.83,7.69,0.25,0.19,0.15,0.12,0.1,0.09],
    [7.83,8.0,7.83,0.26,0.19,0.15,0.12,0.1,0.09],
    [7.69,7.83,8.0,0.26,0.19,0.15,0.12,0.11,0.09],
    [0.25,0.26,0.26,0.27,0.2,0.15,0.13,0.11,0.09],
    [0.19,0.19,0.19,0.2,0.2,0.16,0.13,0.11,0.09],
    [0.15,0.15,0.15,0.15,0.16,0.16,0.13,0.11,0.09],
    [0.12,0.12,0.12,0.13,0.13,0.13,0.13,0.11,0.1],
    [0.1,0.1,0.11,0.11,0.11,0.11,0.11,0.11,0.1],
    [0.09,0.09,0.09,0.09,0.09,0.09,0.1,0.1,0.1]
])

C_work = np.array( [
    [0.08,0.07,0.07,0.07,0.07,0.07,0.07,0.07,0.07],
    [0.07,0.09,0.08,0.08,0.08,0.08,0.08,0.08,0.08],
    [0.07,0.08,0.1,0.1,0.09,0.09,0.09,0.09,0.09],
    [0.07,0.08,0.1,0.12,0.12,0.11,0.11,0.11,0.11],
    [0.07,0.08,0.09,0.12,0.15,0.15,0.14,0.14,0.14],
    [0.07,0.08,0.09,0.11,0.15,0.2,0.19,0.19,0.19],
    [0.07,0.08,0.09,0.11,0.14,0.19,6.0,5.83,5.69],
    [0.07,0.08,0.09,0.11,0.14,0.19,5.83,6.0,5.83],
    [0.07,0.08,0.09,0.11,0.14,0.19,5.69,5.83,6.0]
])

C_transport = np.array( [
    [10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0],
    [10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0],
    [10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0],
    [10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0],
    [10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0],
    [10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0],
    [10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0],
    [10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0],
    [10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0]
])

contact_matrices = {
    'C' : C_home + C_school + C_work,
    'C_commute' : C_transport
}

# %% [markdown]
# ## Setting parameters for Rapid Transport Model

# %%
# set the contact structure
CH = C_home + C_school + C_work
CT = C_transport
CW = C_home + C_school + C_work
        
# parameters, which should be inffered
beta  = 0.02/24.0       # infection rate
gE    = 1.0/3.0/24.0    # recovery rate of exposed
gA    = 1.0/3.0/24.0    # recovery rate of asymptomatic infectives 
gI    = 1.0/3.0/24.0    # recovery rate of infectives 
rW    = 0.1             # the intercation controle in WORK
rT    = 1.0             # the intercation controle in TRANS

cutoff    = 20 # We ignore D_{i,nm}, when It is less than the vule of cutoff.
trv_restriction = 0.0   # travel restriction: 1.0 means everyone stay home

max_wid = np.argsort(Nw[M])[Nd- 1]
#print("Maxmimum City at Working", max_wid)
max_rid = np.argsort(Nh[M])[Nd- 1]
#print("Maxmimum City of Residence", max_rid)
min_wid = np.argsort(Nw[M])[0]
#print("Minimum City at Working", min_wid)
min_rid = np.argsort(Nh[M])[0]
#print("Minimum City of Residence", min_rid)

M1 = Nd*M
E_0 = np.zeros((M1))
A_0 = np.zeros((M1))
I_0 = np.zeros((M1))

#seed_pop = [
#    (0, 1, 'E', 100),      # Home, age group, model class, seed quantity
#    (10, 2, 'E', 100),      
#    (23, 0, 'E', 100),     
#    (622, 4, 'E', 100),
#    (232, 4, 'E', 100)
#]
s_num = 100
E_0[1*Nd + 0]   += s_num
E_0[2*Nd + 10]  += s_num
E_0[0*Nd + 23]  += s_num
E_0[4*Nd + 622] += s_num
E_0[4*Nd + 232] += s_num
#Is_0[min_wid] += 10
R_0 = np.zeros((M1))
N_0 = np.zeros((M1))
for alp in range(M):
    for i in range(Nd):
        N_0[Nd*alp + i] = Nh[alp,i]
S_0  = N_0 - (E_0 + A_0 + I_0 + R_0)
print("Maximum R", Nh[M,max_rid], Nw[M,max_rid])
print("Maximum w", Nh[M,max_wid], Nw[M,max_wid])
print("Minimum R", Nh[M,min_rid], Nw[M,min_rid])
print("Minimum w", Nh[M,min_wid], Nw[M,min_wid])

# the contact matrix
def contactMatrix(t):
    t_p_24 = t%24
    if t_p_24 < 8.0 or t_p_24 > 18.0:
        return CH
    elif t_p_24 > 9.0 and t_p_24 < 17.0:
        return CW
    else:
        return CT

# set the matarix D_{nm}
#Dnm = census_matrix.copy()

# set the matarix d_{nm}
#dnm = distances.copy()

# instantiate model
geographical_model = 'RapidTransport'
#geographical_model = 'SpacialCompartment'
parameters = {'beta':beta, 'gE':gE, 'gA':gA, 'gI':gI, 'rW':rW, 'rT':rT}
model = pyrossgeo.mft.MeanFieldTheory(geographical_model, model_def, parameters, M, Nd, Dnm, dnm, Area, trv_restriction, cutoff)
# Out:
# Maximum R 24719.0 24436.0
# Maximum w 8320.0 247971.0
# Minimum R 5031.0 4920.0
# Minimum w 5717.0 3356.0
# {'S': 0, 'E': 1, 'A': 2, 'I': 3}
# #Start to calculate fixed variables
# Nonzero element 19387/78269409 8047547.0
# Max index J 930
# Max index I 28
# #Finish calculating fixed variables

# %% [markdown]
# After setting the parameters, the calculation of network model will be started. **The modern laptop can finish this calculation about 10 second.**

# %%
#beta  = 0.020/24.0
rW=0.2

# intialize the model
parameters = {'beta':beta, 'gE':gE, 'gA':gA, 'gI':gI, 'rW':rW, 'rT':rT}
model.initialize(model_def, parameters, trv_restriction)

# duration of simulation
Tf=24*200; Nf=0.25*Tf # Maximum time step equals as Tf/Nf
# simulate model
data_rtm=model.simulate(np.concatenate((S_0, E_0, A_0, I_0)), contactMatrix, Tf, Nf, Ti=0)
# Out:
# {'S': 0, 'E': 1, 'A': 2, 'I': 3}
# #Start to calculate fixed variables
# Nonzero element 19387/78269409 8663275.0
# Max index J 930
# Max index I 28
# #Finish calculating fixed variables
# RapidTransport
# travel restriction 0.0
# cutoff 20.0
# highspeed 0
# #Calculation Start
# Time 101.9939614564623
# Time 200.0545149231437
# Time 300.393031497557
# Time 400.1185833388099
# Time 500.828252522101
# Time 600.1229185322321
# Time 700.869437234946
# Time 800.9063327999938
# Time 900.8040026749172
# Time 1000.9977250661116
# Time 1101.8705889749292
# Time 1200.274239691268
# Time 1301.2014955401169
# Time 1400.243965890506
# Time 1500.1480021725752
# Time 1600.964314411233
# Time 1700.483965360225
# Time 1801.585904655046
# Time 1901.7927113632197
# Time 2000.7441248940336
# Time 2100.9832567946373
# Time 2200.8789146979366
# Time 2300.7452779036507
# Time 2400.349489766226
# Time 2500.885353535634
# Time 2600.371052192951
# Time 2700.7159749522307
# Time 2800.8585104347326
# ...

# %% [markdown]
# Loading the results.

# %%
S_RTM = []
E_RTM = []
A_RTM = []
I_RTM = []

for i in range(Nd*M):
    S_RTM.append(data_rtm.get('X')[i].flatten())
    E_RTM.append(data_rtm.get('X')[i + M1].flatten())
    A_RTM.append(data_rtm.get('X')[i + 2*M1].flatten())
    I_RTM.append(data_rtm.get('X')[i + 3*M1].flatten())
t = data_rtm['t']

rtm_community_data = np.zeros((len(t), M, 5, Nd))
for tt in range(len(t)):
    for i in range(M):
        for n in range(Nd):
            rtm_community_data[tt, i, 0, n] = S_RTM[i*Nd + n][tt]
            rtm_community_data[tt, i, 1, n] = E_RTM[i*Nd + n][tt]
            rtm_community_data[tt, i, 2, n] = A_RTM[i*Nd + n][tt]
            rtm_community_data[tt, i, 3, n] = I_RTM[i*Nd + n][tt]
            rtm_community_data[tt, i, 4, n] = Nh[i,n] - (S_RTM[i*Nd + n][tt] + E_RTM[i*Nd + n][tt] + A_RTM[i*Nd + n][tt] + I_RTM[i*Nd + n][tt])

# In 1 dimension, the data index in age group i and node j can be expressed as i*N_{d} + j.
#| Age group 0 | Age group 1 | Age group 2 | Age group 3 | Age group 4 | Age group 5 | Age group 6 |
#|1,2,...,N_{d}|1,2,...,N_{d}|1,2,...,N_{d}|1,2,...,N_{d}|1,2,...,N_{d}|1,2,...,N_{d}|1,2,...,N_{d}|

# %% [markdown]
# ## Setting parameters and the calculation for Spacial Compartment Model

# %%
# instantiate model
geographical_model = 'SpacialCompartment'
parameters = {'beta':beta, 'gE':gE, 'gA':gA, 'gI':gI, 'rW':rW, 'rT':rT}
model = pyrossgeo.mft.MeanFieldTheory(geographical_model, model_def, parameters, M, Nd, Dnm, dnm, Area, trv_restriction, cutoff)

# duration of simulation
Tf=24*200; Nf=(1.0/48.0)*Tf # Spacial Compartment Model #Maximum time step equals as Tf/Nf
# simulate model
data=model.simulate(np.concatenate((S_0, E_0, A_0, I_0)), contactMatrix, Tf, Nf, Ti=0)
# Out:
# {'S': 0, 'E': 1, 'A': 2, 'I': 3}
# #Start to calculate fixed variables
# Nonzero element 19387/78269409 8663275.0
# Max index J 930
# Max index I 28
# #Finish calculating fixed variables
# SpacialCompartment
# travel restriction 0.0
# cutoff 20.0
# highspeed 0
# #Calculation Start
# Time 104.27429879612436
# Time 202.39926858206005
# Time 300.8663462317297
# Time 407.094034982887
# Time 503.00411034207497
# Time 604.0684712098157
# Time 705.3338693145848
# Time 804.2349253739903
# Time 900.7532360662819
# Time 1005.0760830932013
# Time 1104.7661460643662
# Time 1208.6588096021387
# Time 1304.2414645392032
# Time 1404.8872578311534
# Time 1509.5769054456441
# Time 1606.1066190541264
# Time 1704.4964712441194
# Time 1816.7445831836262
# Time 1908.9870324160179
# Time 2003.950969486859
# Time 2111.9509694868593
# Time 2207.9509694868593
# Time 2303.9509694868593
# Time 2411.9509694868593
# Time 2507.9509694868593
# Time 2603.9509694868593
# Time 2723.9509694868593
# ...

# %% [markdown]
# Loading the results of spacial compartment model

# %%
S_SCM = []
E_SCM = []
A_SCM = []
I_SCM = []

for i in range(Nd*M):
    S_SCM.append(data.get('X')[i].flatten())
    E_SCM.append(data.get('X')[i + M1].flatten())
    A_SCM.append(data.get('X')[i + 2*M1].flatten())
    I_SCM.append(data.get('X')[i + 3*M1].flatten())
t = data['t']

scm_community_data = np.zeros((len(t), M, 5, Nd))
for tt in range(len(t)):
    for i in range(M):
        for n in range(Nd):
            scm_community_data[tt, i, 0, n] = S_SCM[i*Nd + n][tt]
            scm_community_data[tt, i, 1, n] = E_SCM[i*Nd + n][tt]
            scm_community_data[tt, i, 2, n] = A_SCM[i*Nd + n][tt]
            scm_community_data[tt, i, 3, n] = I_SCM[i*Nd + n][tt]
            scm_community_data[tt, i, 4, n] = Nh[i,n] - (S_SCM[i*Nd + n][tt] + E_SCM[i*Nd + n][tt] + A_SCM[i*Nd + n][tt] + I_SCM[i*Nd + n][tt])

# In 1 dimension, the data index in age group i and node j can be expressed as i*N_{d} + j.
#| Age group 0 | Age group 1 | Age group 2 | Age group 3 | Age group 4 | Age group 5 | Age group 6 |
#|1,2,...,N_{d}|1,2,...,N_{d}|1,2,...,N_{d}|1,2,...,N_{d}|1,2,...,N_{d}|1,2,...,N_{d}|1,2,...,N_{d}|

# %% [markdown]
# Plotting the results

# %%
fig = plt.figure(num=None, figsize=(10,7), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 22})

total_w = 0.0
total_r = 0.0
for i in range(Nd):
    total_w += Nw[M,i]
    total_r += Nh[M,i]
print('Toatl', total_w, total_r)

S_total = []
E_total = []
A_total = []
I_total = []
#R_total = []
for i in range(len(S_RTM[0])):
    S_total.append(0.0)
    E_total.append(0.0)
    A_total.append(0.0)
    I_total.append(0.0)
    #R_total.append(0.0)
for i in range(M1):
    S_total  += S_RTM[i]
    E_total  += E_RTM[i]
    A_total  += A_RTM[i]
    I_total  += I_RTM[i]
plt.plot(t/24, S_total, '-', label='Rapid Transport, S', lw=2)
plt.plot(t/24, E_total, '-', label='Rapid Transport, E', lw=2)
plt.plot(t/24, A_total, '-', label='Rapid Transport, A', lw=2)
plt.plot(t/24, I_total, '-', label='Rapid Transport, I', lw=2)
plt.plot(t/24, total_r - (S_total + E_total + A_total + I_total), '-', label='Rapid Transport, R', lw=2)
plt.legend(fontsize=18); plt.grid() 
plt.xlabel('Days')
plt.ylabel('S, E+A+I and R')
fig.savefig("London_EpidemicCurve-RTM.png")

f_data = open('network-SEAIR-RTM.txt', mode='w')
for i in range(len(t)):
    f_data.write(str(t[i]/24) + ' ' + str(S_total[i]) + ' ' + str(E_total[i]) + ' ' + str(A_total[i]) + ' ' + str(I_total[i]) + '\n')
f_data.close()
# Out:
# Toatl 8663275.0 8663275.0

# %%
fig = plt.figure(num=None, figsize=(10,7), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 22})

total_w = 0.0
total_r = 0.0
for i in range(Nd):
    total_w += Nw[M,i]
    total_r += Nh[M,i]
print('Toatl', total_w, total_r)

S_total = []
E_total = []
A_total = []
I_total = []
#R_total = []
for i in range(len(S_SCM[0])):
    S_total.append(0.0)
    E_total.append(0.0)
    A_total.append(0.0)
    I_total.append(0.0)
    #R_total.append(0.0)
for i in range(M1):
    S_total  += S_SCM[i]
    E_total  += E_SCM[i]
    A_total  += A_SCM[i]
    I_total  += I_SCM[i]
plt.plot(t/24, S_total, '-', label='Spacial Compartment, S', lw=2)
plt.plot(t/24, E_total, '-', label='Spacial Compartment, E', lw=2)
plt.plot(t/24, A_total, '-', label='Spacial Compartment, A', lw=2)
plt.plot(t/24, I_total, '-', label='Spacial Compartment, I', lw=2)
plt.plot(t/24, total_r - (S_total + E_total + A_total + I_total), '-', label='Spacial Compartment, R', lw=2)
plt.legend(fontsize=18); plt.grid() 
plt.xlabel('Days')
plt.ylabel('S, E+A+I and R')
fig.savefig("London_EpidemicCurve-SCM.png")

f_data = open('network-SEAIR-SCM.txt', mode='w')
for i in range(len(t)):
    f_data.write(str(t[i]/24) + ' ' + str(S_total[i]) + ' ' + str(E_total[i]) + ' ' + str(A_total[i]) + ' ' + str(I_total[i]) + '\n')
f_data.close()
# Out:
# Toatl 8663275.0 8663275.0

# %%
fig = plt.figure(num=None, figsize=(10,7), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 22})

total_w = 0.0
total_r = 0.0
for i in range(Nd):
    total_w += Nw[M,i]
    total_r += Nh[M,i]
print('Toatl', total_w, total_r)

RTM_total = []
SCM_total = []
for i in range(len(S_SCM[0])):
    RTM_total.append(0.0)
    SCM_total.append(0.0)
for i in range(M1):
    RTM_total  += E_RTM[i] + A_RTM[i] + I_RTM[i]
    SCM_total  += E_SCM[i] + A_SCM[i] + I_SCM[i]

plt.plot(t/24, RTM_total, '-', label='Rapid Transport', lw=2)
plt.plot(t/24, SCM_total, '-', label='Spacial Compartment', lw=2)
plt.legend(fontsize=18); plt.grid() 
plt.xlabel('Days')
plt.ylabel('E+A+I')
fig.savefig("London_EpidemicCurve-RTM-SCM.png")
# Out:
# Toatl 8663275.0 8663275.0

# %% [markdown]
# ## Spacial distibution of S,E,A,I and R

# %%
import pickle
import tempfile
#import geopandas as gpd
from geopandas.plotting import plot_polygon_collection
from matplotlib import animation

# Simulation data


N_ = np.zeros((len(t), Nd))
for tt in range(len(t)):
        for n in range(Nd):
            N_[tt, n] = Nh[M,n]

#Rapid Transport
S_RTM_ = np.sum(rtm_community_data[:,:,0,:], axis=1)
E_RTM_ = np.sum(rtm_community_data[:,:,1,:], axis=1)
A_RTM_ = np.sum(rtm_community_data[:,:,2,:], axis=1)
I_RTM_ = np.sum(rtm_community_data[:,:,3,:], axis=1)
R_RTM_ = np.sum(rtm_community_data[:,:,4,:], axis=1)

s_rtm_ = S_RTM_ / N_
e_rtm_ = E_RTM_ / N_
a_rtm_ = A_RTM_ / N_
i_rtm_ = I_RTM_ / N_
r_rtm_ = R_RTM_ / N_

#Spacial Compartment
S_SCM_ = np.sum(scm_community_data[:,:,0,:], axis=1)
E_SCM_ = np.sum(scm_community_data[:,:,1,:], axis=1)
A_SCM_ = np.sum(scm_community_data[:,:,2,:], axis=1)
I_SCM_ = np.sum(scm_community_data[:,:,3,:], axis=1)
R_SCM_ = np.sum(scm_community_data[:,:,4,:], axis=1)

s_scm_ = S_SCM_ / N_
e_scm_ = E_SCM_ / N_
a_scm_ = A_SCM_ / N_
i_scm_ = I_SCM_ / N_
r_scm_ = R_SCM_ / N_

ts_days = t/24

# Load geometry

geometry_node_key = 'msoa11cd'
geometry = gpd.read_file("shape/Middle_Layer_Super_Output_Areas_December_2011_Boundaries_EW_BGC.shp")

loc_table = pd.read_csv('london_simulation/loc_table.csv')
loc_table_loc_col = loc_table.columns[0]
loc_table_loc_key_col = loc_table.columns[1]

geometry = geometry[ geometry[geometry_node_key].isin(loc_table.iloc[:,1]) ] # Remove locations in geometry that are not in loc_table
geometry = geometry.merge(loc_table, left_on=geometry_node_key, right_on=loc_table_loc_key_col) # Add location indices
geometry = geometry.sort_values(by=loc_table_loc_col) # Sort them by location indices

# Edit this function to adjust the layout of the video

def plot_frame(ti, close_plot=False, tmp_save=None):
    fig, axes = plt.subplots(ncols=3, nrows=2, gridspec_kw={'width_ratios':[1, 1, 1.3]}, figsize=(18, 14))

    geometry['S'] = s_[ti,:]
    geometry['E'] = e_[ti,:]
    geometry['A'] = a_[ti,:]
    geometry['I'] = i_[ti,:]
    geometry['R'] = r_[ti,:]
    
    plot_geo(geometry, axes[0,0], vmin=0, vmax=1, value_key='S', title="Susceptible", legend=False)
    plot_geo(geometry, axes[0,1], vmin=0, vmax=1, value_key='E', title="Exposed", legend=False)
    plot_geo(geometry, axes[0,2], vmin=0, vmax=1, value_key='A', title="Activated", legend=True)
    plot_geo(geometry, axes[1,0], vmin=0, vmax=1, value_key='I', title="Infected", legend=False)
    plot_geo(geometry, axes[1,1], vmin=0, vmax=1, value_key='R', title="Recovered", legend=False)
    
    plot_epi(axes[1,2], ti, ts_days, epi_data, ['S','E','A','I','R'])
    
    fig.tight_layout(rect=[0, 0.03, 1, 0.92])
    fig.suptitle("SEAIR Model - Day %s" % ti, fontsize=18)
    
    if not tmp_save is None:
        plt.savefig(tmp_save.name + '/%s.png' % ti)
    if close_plot:
        plt.close(fig)
    if not tmp_save is None:
        return tmp_save.name + '/%s.png' % ti

# Helper functions for plotting

def plot_geo(geometry, ax, vmin, vmax, value_key='val', title="", legend=True, legend_label='', cax=None, axis_on=False):
    if legend:
        if cax is None:
            geometry.plot(column=value_key, ax=ax, vmin=vmin, vmax=vmax, legend=True, legend_kwds={'label': legend_label})
        else:
            geometry.plot(column=value_key, ax=ax, cax=cax, vmin=vmin, vmax=vmax, legend=True, legend_kwds={'label': legend_label})
    else:
        geometry.plot(column=value_key, ax=ax, cax=cax, vmin=vmin, vmax=vmax, legend=False)
        
    ax.set_title(title)
    if not axis_on:
        ax.set_axis_off()
        
def plot_epi(ax, ti, ts, epi_data, epi_data_labels):
    for oi in range(epi_data.shape[0]):
        ax.plot(ts[:ti], epi_data[oi,:ti], label=epi_data_labels[oi])
    ax.legend(loc='center left')
    
    ax.set_xlim(np.min(ts_days), np.max(ts_days))
    ax.set_ylim(0, np.max(epi_data))

# %%
fig, axes = plt.subplots(ncols=4, nrows=2, gridspec_kw={'width_ratios':[1, 1, 1, 1.28]}, figsize=(18, 9))

fig.suptitle('Susceptible', fontsize=28)

dday = 40

geometry['R0'] = s_rtm_[0*dday,:]
geometry['R10'] = s_rtm_[1*dday,:]
geometry['R20'] = s_rtm_[2*dday,:]
geometry['R30'] = s_rtm_[3*dday,:]

geometry['S0'] = s_scm_[0*dday,:]
geometry['S10'] = s_scm_[1*dday,:]
geometry['S20'] = s_scm_[2*dday,:]
geometry['S30'] = s_scm_[3*dday,:]
    
plot_geo(geometry, axes[0,0], vmin=0, vmax=1, value_key='R0', title='%s day' % (0*dday), legend=False)
plot_geo(geometry, axes[0,1], vmin=0, vmax=1, value_key='R10', title='%s day' % (1*dday), legend=False)
plot_geo(geometry, axes[0,2], vmin=0, vmax=1, value_key='R20', title='%s day' % (2*dday), legend=False)
plot_geo(geometry, axes[0,3], vmin=0, vmax=1, value_key='R30', title='%s day' % (3*dday), legend=True, legend_label='Rapid transport')
plot_geo(geometry, axes[1,0], vmin=0, vmax=1, value_key='S0', title='%s day' % (0*dday), legend=False)
plot_geo(geometry, axes[1,1], vmin=0, vmax=1, value_key='S10', title='%s day' % (1*dday), legend=False)
plot_geo(geometry, axes[1,2], vmin=0, vmax=1, value_key='S20', title='%s day' % (2*dday), legend=False)
plot_geo(geometry, axes[1,3], vmin=0, vmax=1, value_key='S30', title='%s day' % (3*dday), legend=True, legend_label='Spacial Compartment')
fig.savefig('Susceptible.png')

# %%
fig, axes = plt.subplots(ncols=4, nrows=2, gridspec_kw={'width_ratios':[1, 1, 1, 1.28]}, figsize=(18, 9))

fig.suptitle('Exposed', fontsize=28)

dday = 40

geometry['R0'] = e_rtm_[0*dday,:]
geometry['R10'] = e_rtm_[1*dday,:]
geometry['R20'] = e_rtm_[2*dday,:]
geometry['R30'] = e_rtm_[3*dday,:]

geometry['S0'] = e_scm_[0*dday,:]
geometry['S10'] = e_scm_[1*dday,:]
geometry['S20'] = e_scm_[2*dday,:]
geometry['S30'] = e_scm_[3*dday,:]
    
plot_geo(geometry, axes[0,0], vmin=0, vmax=1, value_key='R0', title='%s day' % (0*dday), legend=False)
plot_geo(geometry, axes[0,1], vmin=0, vmax=1, value_key='R10', title='%s day' % (1*dday), legend=False)
plot_geo(geometry, axes[0,2], vmin=0, vmax=1, value_key='R20', title='%s day' % (2*dday), legend=False)
plot_geo(geometry, axes[0,3], vmin=0, vmax=1, value_key='R30', title='%s day' % (3*dday), legend=True, legend_label='Rapid transport')
plot_geo(geometry, axes[1,0], vmin=0, vmax=1, value_key='S0', title='%s day' % (0*dday), legend=False)
plot_geo(geometry, axes[1,1], vmin=0, vmax=1, value_key='S10', title='%s day' % (1*dday), legend=False)
plot_geo(geometry, axes[1,2], vmin=0, vmax=1, value_key='S20', title='%s day' % (2*dday), legend=False)
plot_geo(geometry, axes[1,3], vmin=0, vmax=1, value_key='S30', title='%s day' % (3*dday), legend=True, legend_label='Spacial Compartment')
fig.savefig('Exposed.png')

# %%
fig, axes = plt.subplots(ncols=4, nrows=2, gridspec_kw={'width_ratios':[1, 1, 1, 1.28]}, figsize=(18, 9))

fig.suptitle('Asymptomatic and Infectious', fontsize=28)

geometry['R0']  = a_rtm_[0*dday,:]
geometry['R10'] = a_rtm_[1*dday,:]
geometry['R20'] = a_rtm_[2*dday,:]
geometry['R30'] = a_rtm_[3*dday,:]

geometry['S0']  = a_scm_[0*dday,:]
geometry['S10'] = a_scm_[1*dday,:]
geometry['S20'] = a_scm_[2*dday,:]
geometry['S30'] = a_scm_[3*dday,:]
    
plot_geo(geometry, axes[0,0], vmin=0, vmax=1, value_key='R0', title='%s day' % (0*dday), legend=False)
plot_geo(geometry, axes[0,1], vmin=0, vmax=1, value_key='R10', title='%s day' % (1*dday), legend=False)
plot_geo(geometry, axes[0,2], vmin=0, vmax=1, value_key='R20', title='%s day' % (2*dday), legend=False)
plot_geo(geometry, axes[0,3], vmin=0, vmax=1, value_key='R30', title='%s day' % (3*dday), legend=True, legend_label='Rapid transport')
plot_geo(geometry, axes[1,0], vmin=0, vmax=1, value_key='S0', title='%s day' % (0*dday), legend=False)
plot_geo(geometry, axes[1,1], vmin=0, vmax=1, value_key='S10', title='%s day' % (1*dday), legend=False)
plot_geo(geometry, axes[1,2], vmin=0, vmax=1, value_key='S20', title='%s day' % (2*dday), legend=False)
plot_geo(geometry, axes[1,3], vmin=0, vmax=1, value_key='S30', title='%s day' % (3*dday), legend=True, legend_label='Spacial Compartment')
fig.savefig('Asymptomatic.png')

# %%
fig, axes = plt.subplots(ncols=4, nrows=2, gridspec_kw={'width_ratios':[1, 1, 1, 1.28]}, figsize=(18, 9))

fig.suptitle('Infectives', fontsize=28)

geometry['R0'] = i_rtm_[0*dday,:]
geometry['R10'] = i_rtm_[1*dday,:]
geometry['R20'] = i_rtm_[2*dday,:]
geometry['R30'] = i_rtm_[3*dday,:]

geometry['S0']  = i_scm_[0*dday,:]
geometry['S10'] = i_scm_[1*dday,:]
geometry['S20'] = i_scm_[2*dday,:]
geometry['S30'] = i_scm_[3*dday,:]
    
plot_geo(geometry, axes[0,0], vmin=0, vmax=1, value_key='R0', title='%s day' % (0*dday), legend=False)
plot_geo(geometry, axes[0,1], vmin=0, vmax=1, value_key='R10', title='%s day' % (1*dday), legend=False)
plot_geo(geometry, axes[0,2], vmin=0, vmax=1, value_key='R20', title='%s day' % (2*dday), legend=False)
plot_geo(geometry, axes[0,3], vmin=0, vmax=1, value_key='R30', title='%s day' % (3*dday), legend=True, legend_label='Rapid transport')
plot_geo(geometry, axes[1,0], vmin=0, vmax=1, value_key='S0', title='%s day' % (0*dday), legend=False)
plot_geo(geometry, axes[1,1], vmin=0, vmax=1, value_key='S10', title='%s day' % (1*dday), legend=False)
plot_geo(geometry, axes[1,2], vmin=0, vmax=1, value_key='S20', title='%s day' % (2*dday), legend=False)
plot_geo(geometry, axes[1,3], vmin=0, vmax=1, value_key='S30', title='%s day' % (3*dday), legend=True, legend_label='Spacial Compartment')
fig.savefig('Infectives.png')

# %%
fig, axes = plt.subplots(ncols=4, nrows=2, gridspec_kw={'width_ratios':[1, 1, 1, 1.28]}, figsize=(18, 9))

fig.suptitle('Recovered', fontsize=28)

geometry['R0'] = r_rtm_[0*dday,:]
geometry['R10'] = r_rtm_[1*dday,:]
geometry['R20'] = r_rtm_[2*dday,:]
geometry['R30'] = r_rtm_[3*dday,:]
    
geometry['S0']  = r_scm_[0*dday,:]
geometry['S10'] = r_scm_[1*dday,:]
geometry['S20'] = r_scm_[2*dday,:]
geometry['S30'] = r_scm_[3*dday,:]
    
plot_geo(geometry, axes[0,0], vmin=0, vmax=1, value_key='R0', title='%s day' % (0*dday), legend=False)
plot_geo(geometry, axes[0,1], vmin=0, vmax=1, value_key='R10', title='%s day' % (1*dday), legend=False)
plot_geo(geometry, axes[0,2], vmin=0, vmax=1, value_key='R20', title='%s day' % (2*dday), legend=False)
plot_geo(geometry, axes[0,3], vmin=0, vmax=1, value_key='R30', title='%s day' % (3*dday), legend=True, legend_label='Rapid transport')
plot_geo(geometry, axes[1,0], vmin=0, vmax=1, value_key='S0', title='%s day' % (0*dday), legend=False)
plot_geo(geometry, axes[1,1], vmin=0, vmax=1, value_key='S10', title='%s day' % (1*dday), legend=False)
plot_geo(geometry, axes[1,2], vmin=0, vmax=1, value_key='S20', title='%s day' % (2*dday), legend=False)
plot_geo(geometry, axes[1,3], vmin=0, vmax=1, value_key='S30', title='%s day' % (3*dday), legend=True, legend_label='Spacial Compartment')
fig.savefig('Removed.png')

# %%
geometry['st_areasha'].to_csv('area.csv')
